# %%
import re

# %%
pip install regex
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
a="Hello this data science class, Contact this number 9874651230"

b=r"\d+"
b
# Out:
# '\\d+'

# %%
c=re.search(b,a)
c
# Out:
# <re.Match object; span=(51, 61), match='9874651230'>

# %%
import re

text = "The order number is 987654."
pattern = r"\d+"  # Matches one or more digits

match = re.search(pattern, text)
if match:
    print("Found:", match.group())  # Output: Found: 987654
# Out:
# Found: 987654

# %%
c=re.compile("ab.")
d=c.findall(("abcabbaabbbb"))
d
# Out:
# ['abc', 'abb', 'abb']

# %%
c1=re.sub("a","**","Data Science")
c1
# Out:
# 'D**t** Science'

# %%
c=re.match(r"Hello",a)
c.group()
# Out:
# 'Hello'
