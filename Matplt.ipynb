# %%
import pandas as pd

# %%
d=pd.read_csv("student_performance.csv")
d
# Out:
#         student_id  weekly_self_study_hours  attendance_percentage  \
# 0                1                     18.5                   95.6
# 1                2                     14.0                   80.0
# 2                3                     19.5                   86.3
# 3                4                     25.7                   70.2
# 4                5                     13.4                   81.9
# ...            ...                      ...                    ...
# 999995      999996                     18.0                   95.5
# 999996      999997                     15.7                   82.7
# 999997      999998                     14.2                   85.1
# 999998      999999                     25.3                   90.0
# 999999     1000000                     18.3                   84.6
#
#         class_participation  total_score grade
# 0                       3.8         97.9     A
# 1                       2.5         83.9     B
# ...

# %%
d.columns
# Out:
# Index(['student_id', 'weekly_self_study_hours', 'attendance_percentage',
#        'class_participation', 'total_score', 'grade'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

# %%
d.isnull().any()
# Out:
# student_id                 False
# weekly_self_study_hours    False
# attendance_percentage      False
# class_participation        False
# total_score                False
# grade                      False
# dtype: bool

# %%
d.groupby("grade")[["total_score","weekly_self_study_hours"]].mean().plot(kind="bar")
plt.title("Grade vs Total_Score")
plt.xlabel("Grade")
plt.ylabel("Total Score")
plt.show()

# %%
c=["KitKat","Dairy Milk","5star","Brownie"]
p=[250,900,550,800]
plt.bar(c,p,color=["red","blue","yellow","brown"])
plt.xlabel("Choclate")
plt.ylabel("Price")
plt.show()

# %%
mark=[89,91,45,67,92,99,97,54,53,52,100]
plt.hist(mark)
plt.show()

# %%
plt.hist(d["total_score"],bins=20)
plt.title("Distribution of Score")
plt.show()

# %%
plt.plot(c,p)
plt.show()

# %%
d["grade"].value_counts().plot(kind="pie",autopct="%1.1f%%")
plt.show()

# %%
s=d["grade"].value_counts()
s
# Out:
# grade
# A    548644
# B    258174
# C    141980
# D     44998
# F      6204
# Name: count, dtype: int64

# %%
plt.boxplot([d["weekly_self_study_hours"],d["total_score"]])
plt.show()
