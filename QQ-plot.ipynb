# %%
import pandas as pd

df = pd.read_csv("Mall_Customers.csv")
df
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import scipy.stats as stats

# %%
stats.probplot(df["Age"],dist="norm",plot=plt)
plt.show()

# %%
import numpy as np

# %%
normal_dist=np.random.binomial(n=10,size=100,p=0.2)
normal_dist
# Out:
# array([4, 2, 1, 2, 3, 2, 3, 3, 3, 2, 4, 1, 3, 3, 2, 2, 2, 0, 3, 1, 1, 1,
#        1, 1, 1, 0, 5, 1, 3, 2, 3, 3, 3, 5, 2, 0, 3, 3, 2, 1, 1, 3, 2, 2,
#        0, 2, 4, 2, 2, 0, 2, 2, 4, 5, 1, 0, 1, 3, 0, 1, 0, 4, 3, 3, 2, 3,
#        2, 2, 3, 4, 3, 3, 1, 2, 2, 2, 0, 4, 1, 4, 0, 3, 3, 2, 2, 1, 4, 0,
#        1, 3, 1, 2, 2, 2, 3, 1, 2, 4, 2, 1], dtype=int32)

# %%
import statsmodels.api as sm

# %%
import pylab as py

# %%
sm.qqplot(normal_dist)
plt.show()

# %%
sm.qqplot(normal_dist,line="45")
plt.show()
